# %%
import anndata
import numpy as np
import pandas as pd
import scanpy as sc

# %%
rna = anndata.read_h5ad("/lmh_data/data/sclab/sclab/mouse/rna_result.h5ad")
hic = anndata.read_h5ad("/lmh_data/data/sclab/sclab/mouse/hic_result.h5ad")

# %%
combined = anndata.concat([rna, hic])
sc.pp.neighbors(combined, use_rep="X_glue", metric="cosine")
sc.tl.umap(combined)
sc.pl.umap(combined, color=["cell_type", "domain"], wspace=0.65)
# Out:
# /root/miniconda3/envs/see/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /root/miniconda3/envs/see/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
combined
# Out:
# AnnData object with n_obs × n_vars = 1183 × 0
#     obs: 'cell_type', 'domain', 'leiden', 'balancing_weight'
#     uns: 'neighbors', 'umap', 'cell_type_colors', 'domain_colors'
#     obsm: 'X_glue', 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
_con = pd.DataFrame(combined.obsp['connectivities'].toarray(), columns=combined.obs_names, index=combined.obs_names)
_con = _con.loc[
    combined.obs[combined.obs['domain']=='scRNA'].index,
    combined.obs[combined.obs['domain']=='scHiC'].index
]
_con
# Out:
#                                      cortex-p309-bc_129  cortex-p028-cb_005  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0                 0.0
# ...                                                 ...                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0                 0.0
#
#                                      cortex-p309-bc_151  cortex-p056-cb_014  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09            0.000000            0.000000
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09            0.000000            0.000000
# CTACGTCAGTAATCCC-L8TX_180221_01_A10            0.089843            0.492623
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10            0.000000            0.000000
# TCATTACAGGGAGTAA-L8TX_180221_01_B10            0.000000            0.000000
# ...                                                 ...                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12            0.000000            0.000000
# CGATCGGCACCAGATT-L8TX_200611_02_A05            0.000000            0.000000
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05            0.000000            0.000000
# GATCAGTCATCCGTGG-L8TX_200611_02_A05            0.000000            0.000000
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05            0.000000            0.000000
#
#                                      hippocampus-p028-cb_081  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                      0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                      0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                      0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                      0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                      0.0
# ...                                                      ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                      0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                      0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                      0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                      0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                      0.0
#
#                                      hippocampus-p028-cb_059  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                      0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                      0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                      0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                      0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                      0.0
# ...                                                      ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                      0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                      0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                      0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                      0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                      0.0
#
#                                      cortex-p056-cb_001  cortex-p028-cb_221  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0                 0.0
# ...                                                 ...                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0                 0.0
#
#                                      cortex-p001-cb_021  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0
# ...                                                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0
#
#                                      hippocampus-p028-cb_006  ...  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                      0.0  ...
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                      0.0  ...
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                      0.0  ...
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                      0.0  ...
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                      0.0  ...
# ...                                                      ...  ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                      0.0  ...
# CGATCGGCACCAGATT-L8TX_200611_02_A05                      0.0  ...
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                      0.0  ...
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                      0.0  ...
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                      0.0  ...
#
#                                      cortex-p007-cb_047  cortex-p028-cb_207  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0                 0.0
# ...                                                 ...                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0                 0.0
#
#                                      cortex-p028-cb_162  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09            0.000000
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09            0.000000
# CTACGTCAGTAATCCC-L8TX_180221_01_A10            0.000000
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10            0.000000
# TCATTACAGGGAGTAA-L8TX_180221_01_B10            0.000000
# ...                                                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12            0.000000
# CGATCGGCACCAGATT-L8TX_200611_02_A05            0.000000
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05            0.000000
# GATCAGTCATCCGTGG-L8TX_200611_02_A05            0.210851
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05            0.000000
#
#                                      hippocampus-p001-cb_172  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                      0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                      0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                      0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                      0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                      0.0
# ...                                                      ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                      0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                      0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                      0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                      0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                      0.0
#
#                                      cortex-p309-bc_122  cortex-p056-cb_004  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09             0.62284                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09             0.00000                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10             0.00000                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10             0.00000                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10             0.00000                 0.0
# ...                                                 ...                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12             0.00000                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05             0.00000                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05             0.00000                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05             0.00000                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05             0.00000                 0.0
#
#                                      hippocampus-p056-cb_078  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                      0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                      0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                      0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                      0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                      0.0
# ...                                                      ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                      0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                      0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                      0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                      0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                      0.0
#
#                                      cortex-p028-cb_026  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0
# ...                                                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0
#
#                                      hippocampus-p309-bc_043  \
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.071691
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.000000
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.000000
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.000000
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.000000
# ...                                                      ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.000000
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.000000
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.000000
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.000000
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.000000
#
#                                      cortex-p056-cb_024
# CTGCCTAGTACGCACC-L8TX_180221_01_F09                 0.0
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09                 0.0
# CTACGTCAGTAATCCC-L8TX_180221_01_A10                 0.0
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10                 0.0
# TCATTACAGGGAGTAA-L8TX_180221_01_B10                 0.0
# ...                                                 ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12                 0.0
# CGATCGGCACCAGATT-L8TX_200611_02_A05                 0.0
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05                 0.0
# GATCAGTCATCCGTGG-L8TX_200611_02_A05                 0.0
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05                 0.0
#
# [650 rows x 533 columns]

# %%
_map = pd.DataFrame()
for cell_type in combined.obs.cell_type.unique():
    _sub = combined[combined.obs[combined.obs['cell_type']==cell_type].index, :].copy()
    _con = pd.DataFrame(_sub.obsp['connectivities'].toarray(), columns=_sub.obs_names, index=_sub.obs_names)
    _con = _con.loc[_sub.obs[_sub.obs['domain']=='scRNA'].index, _sub.obs[_sub.obs['domain']=='scHiC'].index]
    _con = _con[_con.apply(np.sum, axis=1) != 0]
    _result = pd.DataFrame(_con.idxmax(1), columns=['scHiC'])
    _result['cell_type'] = cell_type
    _map = pd.concat([_map, _result])
_map
# Out:
#                                                        scHiC cell_type
# CTGCCTAGTACGCACC-L8TX_180221_01_F09  hippocampus-p347-cb_048     Astro
# GATGAGGAGAAGCCCA-L8TX_180221_01_F09  hippocampus-p309-bc_166     Astro
# TTAGTTCTCAGCAACT-L8TX_180221_01_A10       cortex-p028-cb_196     Astro
# AGCGTCGCATGCATGT-L8TX_180406_01_C06       cortex-p056-cb_048     Astro
# ACGAGGAAGGACAGAA-L8TX_180221_01_C09       cortex-p001-cb_030     Astro
# ...                                                      ...       ...
# CTCTACGCACGGACAA-L8TX_180221_01_D12  hippocampus-p347-cb_023     Oligo
# CGATCGGCACCAGATT-L8TX_200611_02_A05       cortex-p028-cb_082     Oligo
# CTAGCCTGTTCGCGAC-L8TX_200611_02_A05       cortex-p028-cb_183     Oligo
# GATCAGTCATCCGTGG-L8TX_200611_02_A05       cortex-p028-cb_126     Oligo
# GGGTCTGAGTGAACAT-L8TX_200611_02_A05       cortex-p028-cb_077     Oligo
#
# [644 rows x 2 columns]

# %%
_map.to_csv("/lmh_data/data/sclab/sclab/mouse/map_result.csv", sep='\t')
