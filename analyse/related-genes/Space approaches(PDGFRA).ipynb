# %%
import os
import random
from multiprocessing import Pool

import anndata
import cooler
import numpy as np
import pandas as pd
from tqdm import tqdm

root_dir = '/lmh_data/data/sclab'
threads = 48
random.seed(0)

map_info = pd.read_csv(os.path.join(root_dir, 'sclab', 'map_result.csv'), sep='\t', index_col=0)
# hic
cools_path = os.path.join(root_dir, 'Lee2019', 'Human_single_cell_10kb_cool')
hic = anndata.read_h5ad(os.path.join(root_dir, 'sclab', 'hic_result.h5ad'))
# rna
rna = anndata.read_h5ad(os.path.join(root_dir, 'sclab', 'rna_result.h5ad'))
rna_marker_gene = pd.read_csv(os.path.join(root_dir, 'sclab', 'rna_marker_gene.csv'), sep='\t', index_col=0)
_tmp = rna.var.loc[rna_marker_gene.index]
_tmp = _tmp[_tmp['chromEnd'] > _tmp['chromStart'] + 50000]
rna_marker_gene = rna_marker_gene.loc[_tmp.index]

# %%
hic = hic[hic.obs['cell_type']=='OPC']

def get_cooler(hic_name):
    file_name = '{}_10kb_contacts.cool'.format(hic_name)
    return hic_name, cooler.Cooler(os.path.join(cools_path, file_name))
with Pool(threads) as p:
    _coolers = dict(p.map(get_cooler, hic.obs_names))
    
def catch_matrix(_args):
    hic_name, gene_name_1, gene_name_2 = _args
    _gene_info_1, _gene_info_2 = rna.var.loc[gene_name_1], rna.var.loc[gene_name_2]
    mat = _coolers[hic_name].matrix(balance=False).fetch(
        '{}:{}-{}'.format(_gene_info_1['chrom'], int(_gene_info_1['chromStart']), int(_gene_info_1['chromEnd'])),
        '{}:{}-{}'.format(_gene_info_2['chrom'], int(_gene_info_2['chromStart']), int(_gene_info_2['chromEnd'])),
    )
    return gene_name_2, mat.sum()

# %%
_contacts = pd.DataFrame()
for hic_name in tqdm(hic.obs_names):
    with Pool(threads) as p:
        _args = [(hic_name, 'PDGFRA', gene_name) for gene_name in rna.var_names]
        _contact = pd.DataFrame([dict(p.map(catch_matrix, _args))], index=[hic_name])
    _contacts = pd.concat([_contacts, _contact], axis=0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 203/203 [28:21<00:00,  8.38s/it]

# %%
_contacts
# Out:
#                              DDX11L1  WASH7P  MIR1302-2  FAM138A  OR4G4P  \
# 190315_21yr_6_A10_AD001_OPC        0       0          0        0       0
# 190305_29yr_2_H9_AD008_OPC         0       0          0        0       0
# 190315_21yr_4_G12_AD012_OPC        0       0          0        0       0
# 190315_21yr_4_B11_AD007_OPC        0       0          0        0       0
# 181218_21yr_2_D3_AD008_OPC         0       0          0        0       0
# ...                              ...     ...        ...      ...     ...
# 190315_29yr_4_F8_AD012_OPC         0       0          0        0       0
# 190305_29yr_2_B6_AD004_OPC         0       0          0        0       0
# 190315_21yr_4_D3_AD008_OPC         0       0          0        0       0
# 190315_21yr_6_G12_AD006_OPC        0       0          0        0       0
# 190305_21yr_2_B1_AD001_OPC         0       0          0        0       0
#
#                              OR4G11P  OR4F5  CICP27  OR4F29  CICP7  ...  \
# 190315_21yr_6_A10_AD001_OPC        0      0       0       0      0  ...
# 190305_29yr_2_H9_AD008_OPC         0      0       0       0      0  ...
# 190315_21yr_4_G12_AD012_OPC        0      0       0       0      0  ...
# 190315_21yr_4_B11_AD007_OPC        0      0       0       0      0  ...
# 181218_21yr_2_D3_AD008_OPC         0      0       0       0      0  ...
# ...                              ...    ...     ...     ...    ...  ...
# 190315_29yr_4_F8_AD012_OPC         0      0       0       0      0  ...
# 190305_29yr_2_B6_AD004_OPC         0      0       0       0      0  ...
# 190315_21yr_4_D3_AD008_OPC         0      0       0       0      0  ...
# 190315_21yr_6_G12_AD006_OPC        0      0       0       0      0  ...
# 190305_21yr_2_B1_AD001_OPC         0      0       0       0      0  ...
#
#                              RBMY2DP  PPP1R12BP1  CYCSP48  ANKRD36P1  CYCSP49  \
# 190315_21yr_6_A10_AD001_OPC        0           0        0          0        0
# 190305_29yr_2_H9_AD008_OPC         0           0        0          0        0
# 190315_21yr_4_G12_AD012_OPC        0           0        0          0        0
# 190315_21yr_4_B11_AD007_OPC        0           0        0          0        0
# 181218_21yr_2_D3_AD008_OPC         0           0        0          0        0
# ...                              ...         ...      ...        ...      ...
# 190315_29yr_4_F8_AD012_OPC         0           0        0          0        0
# 190305_29yr_2_B6_AD004_OPC         0           0        0          0        0
# 190315_21yr_4_D3_AD008_OPC         0           0        0          0        0
# 190315_21yr_6_G12_AD006_OPC        0           0        0          0        0
# 190305_21yr_2_B1_AD001_OPC         0           0        0          0        0
#
#                              TPTE2P4  SLC25A15P1  PARP4P1  FAM58CP  CTBP2P1
# 190315_21yr_6_A10_AD001_OPC        0           0        0        0        0
# 190305_29yr_2_H9_AD008_OPC         0           0        0        0        0
# 190315_21yr_4_G12_AD012_OPC        0           0        0        0        0
# 190315_21yr_4_B11_AD007_OPC        0           0        0        0        0
# 181218_21yr_2_D3_AD008_OPC         0           0        0        0        0
# ...                              ...         ...      ...      ...      ...
# 190315_29yr_4_F8_AD012_OPC         0           0        0        0        0
# 190305_29yr_2_B6_AD004_OPC         0           0        0        0        0
# 190315_21yr_4_D3_AD008_OPC         0           0        0        0        0
# 190315_21yr_6_G12_AD006_OPC        0           0        0        0        0
# 190305_21yr_2_B1_AD001_OPC         0           0        0        0        0
#
# [203 rows x 29175 columns]

# %%
_contacts.loc["列总和"] = _contacts.apply(lambda x:x.sum())
_contacts
# Out:
#                              DDX11L1  WASH7P  MIR1302-2  FAM138A  OR4G4P  \
# 190315_21yr_6_A10_AD001_OPC        0       0          0        0       0
# 190305_29yr_2_H9_AD008_OPC         0       0          0        0       0
# 190315_21yr_4_G12_AD012_OPC        0       0          0        0       0
# 190315_21yr_4_B11_AD007_OPC        0       0          0        0       0
# 181218_21yr_2_D3_AD008_OPC         0       0          0        0       0
# ...                              ...     ...        ...      ...     ...
# 190305_29yr_2_B6_AD004_OPC         0       0          0        0       0
# 190315_21yr_4_D3_AD008_OPC         0       0          0        0       0
# 190315_21yr_6_G12_AD006_OPC        0       0          0        0       0
# 190305_21yr_2_B1_AD001_OPC         0       0          0        0       0
# 列总和                                0       0          0        0       0
#
#                              OR4G11P  OR4F5  CICP27  OR4F29  CICP7  ...  \
# 190315_21yr_6_A10_AD001_OPC        0      0       0       0      0  ...
# 190305_29yr_2_H9_AD008_OPC         0      0       0       0      0  ...
# 190315_21yr_4_G12_AD012_OPC        0      0       0       0      0  ...
# 190315_21yr_4_B11_AD007_OPC        0      0       0       0      0  ...
# 181218_21yr_2_D3_AD008_OPC         0      0       0       0      0  ...
# ...                              ...    ...     ...     ...    ...  ...
# 190305_29yr_2_B6_AD004_OPC         0      0       0       0      0  ...
# 190315_21yr_4_D3_AD008_OPC         0      0       0       0      0  ...
# 190315_21yr_6_G12_AD006_OPC        0      0       0       0      0  ...
# 190305_21yr_2_B1_AD001_OPC         0      0       0       0      0  ...
# 列总和                                0      0       0       0      0  ...
#
#                              RBMY2DP  PPP1R12BP1  CYCSP48  ANKRD36P1  CYCSP49  \
# 190315_21yr_6_A10_AD001_OPC        0           0        0          0        0
# 190305_29yr_2_H9_AD008_OPC         0           0        0          0        0
# 190315_21yr_4_G12_AD012_OPC        0           0        0          0        0
# 190315_21yr_4_B11_AD007_OPC        0           0        0          0        0
# 181218_21yr_2_D3_AD008_OPC         0           0        0          0        0
# ...                              ...         ...      ...        ...      ...
# 190305_29yr_2_B6_AD004_OPC         0           0        0          0        0
# 190315_21yr_4_D3_AD008_OPC         0           0        0          0        0
# 190315_21yr_6_G12_AD006_OPC        0           0        0          0        0
# 190305_21yr_2_B1_AD001_OPC         0           0        0          0        0
# 列总和                                0           0        0          0        0
#
#                              TPTE2P4  SLC25A15P1  PARP4P1  FAM58CP  CTBP2P1
# 190315_21yr_6_A10_AD001_OPC        0           0        0        0        0
# 190305_29yr_2_H9_AD008_OPC         0           0        0        0        0
# 190315_21yr_4_G12_AD012_OPC        0           0        0        0        0
# 190315_21yr_4_B11_AD007_OPC        0           0        0        0        0
# 181218_21yr_2_D3_AD008_OPC         0           0        0        0        0
# ...                              ...         ...      ...      ...      ...
# 190305_29yr_2_B6_AD004_OPC         0           0        0        0        0
# 190315_21yr_4_D3_AD008_OPC         0           0        0        0        0
# 190315_21yr_6_G12_AD006_OPC        0           0        0        0        0
# 190305_21yr_2_B1_AD001_OPC         0           0        0        0        0
# 列总和                                0           0        0        0        0
#
# [204 rows x 29175 columns]

# %%
_test = _contacts.loc['列总和'].sort_values(ascending=False)
_test = _test[_test>0]
_test
# Out:
# FIP1L1      6723
# PDGFRA      6155
# SCFD2        325
# LNX1         173
# KIT           48
#             ...
# SERBP1P2       1
# MFAP3L         1
# PEX14          1
# HTR2C          1
# MCC            1
# Name: 列总和, Length: 1025, dtype: int64

# %%
for gene in _test.index:
    print(gene)
# Out:
# FIP1L1
# PDGFRA
# SCFD2
# LNX1
# KIT
# LNX1-AS1
# CHIC2
# USP46
# KIAA1211
# LINC00486
# CLOCK
# DCUN1D4
# ERVMER34-1
# LNX1-AS2
# FRYL
# USP46-AS1
# WRN
# TMEM165
# EPHA5
# RPL21P44
# EXOC1
# RPL38P3
# RASGEF1B
# THEGL
# GLIS1
# MARCH1
# TEC
# KDR
# MACROD2
# SRD5A3
# POP4
# GSX2
# ADAMTS9-AS2
# ZNF704
# GABRB1
# LHPP
# KLHL29
# FHIT
# PTPRD
# UBA6-AS1
# KCTD8
# CDH10
# FUT8
# NMU
# SLAIN2
# SRD5A3-AS1
# FCF1P8
# SGCB
# DANCR
# GRID2
# ARHGAP24
# LINC00504
# RASL11B
# SORCS2
# LDLRAD4-AS1
# LDLRAD4
# MORF4L2P1
# ADAMTS3
# TPD52
# AGBL4
# AASDH
# PPAT
# CLTCL1
# SIL1
# FAM155A
# SPATA18
# GLDCP1
# COLEC12
# STPG2
# MAD2L1
# ZNF536
# CAMK2A
# PACRG
# CDH2
# ZNF804A
# LSAMP
# NKAIN2
# RAD21L1
# SOX5
# JMJD1C
# ARID5B
# SQSTM1
# SNTG1
# PSMG2
# EXOC4
# TRPC5
# TOX2
# AGPS
# LINC00348
# RALGAPB
# FGGY
# GNAI3
# TENM1
# LPP
# NYAP1
# IGFBP7-AS1
# SPINK2
# NFKB1
# TET2
# PAICS
# PRKG1
# PCDHB11
# GREB1L
# GOLGA7
# PDCL2
# CRB1
# MYLK3
# FAM19A5
# ICK
# UNC79
# NSUN7
# ROBO2
# ZFYVE28
# FAM193A
# GRAMD2
# SYNE1
# RELL1
# C4orf50
# TRMT44
# LINC00682
# MLLT4
# OR4C4P
# ASIC2
# ARHGEF10L
# WDR1
# ANKRD34C
# MIR3138
# RGS16
# FGFRL1
# TMEM175
# UBE2H
# PRIM2
# FBXO9
# MEGF9
# CSN1S1
# GALNTL6
# ANPEP
# CLDN10
# CLDN10-AS1
# OR9Q1
# SCIN
# DOCK9
# EPHA6
# SMYD3
# TRHDE
# GABRA2
# METTL10
# FAM53B
# GAK
# DST
# UGT2B7
# SLC39A11
# ZNF675
# HSPA4L
# C2orf15
# RASSF6
# CLEC4C
# USO1
# LAMP3
# RBMXP2
# ACOXL
# CSMD1
# WDSUB1
# CTDSPL2
# NEDD9
# SCN8A
# WDFY3
# PHF11
# ZNF678
# PRDM5
# MIR4451
# ZFP28
# FAT4
# LARGE
# ZNF425
# SPATA5
# HERC3
# BANK1
# RUNX2
# CACNB4
# PTCHD4
# ZNF230
# NPFFR2
# DDX27
# ENAM
# CCNE1
# MAML3
# RUFY3
# MOB1B
# GPM6A
# SPTLC3
# NPAS3
# RTTN
# UTP3
# KCNIP3
# XKR6
# LRP6
# TMEM38B
# BCL2L14
# RGS12
# RNF4
# SYN3
# ARHGAP6
# HAUS3
# LINC00667
# KAL1
# POLN
# WWC3
# C1orf112
# LINC00526
# CTBP1-AS2
# ANKS1A
# TRPM7
# TPRG1
# GRM4
# SELE
# DOK7
# DEC1
# ANKRD19P
# ARNT
# ANP32E
# EPS8
# IFT80
# BOD1L1
# ADAMTS13
# C1orf105
# RNF185
# CLIC5
# TMEM245
# REXO4
# CNOT6LP1
# CSPG4
# STK32B
# DEPDC5
# ACOX3
# USP2-AS1
# RASGRP1
# THY1
# AFAP1-AS1
# SLC5A1
# WDR49
# GPR19
# NPLOC4
# TEX14
# KIAA0195
# CACNA1C
# TMEM207
# SPATA5L1
# MFAP5
# CYCSP40
# CCDC39
# MGST1
# FXR1
# ABL2
# DNAJC19
# CACNA2D4
# SOX2-OT
# SEC14L1
# ZBTB37
# LPPR1
# APOBEC3G
# FCGR2A
# OPA1
# MYL12A
# TMEM14A
# PAQR8
# MCM3
# ABCC5
# YES1
# DNAH8
# TLN2
# ASTN2
# MGST3
# C17orf70
# TRERF1
# CCDC50
# EIF2B5
# NR6A1
# RBFOX2
# RABGAP1
# ETS1
# PRKCA
# C9orf3
# RNF213
# GPA33
# RNA5SP445
# APLP2
# KLRD1
# FRMD5
# PCYT1A
# ZBTB44
# MEI1
# SLC51A
# OPCML
# SSPN
# FSIP1
# EIF3J-AS1
# TCEA1P1
# CASC4
# DACH1
# DMD
# FBXL5
# ZNF33A
# ZNF37A
# PKN2
# LIN54
# SLC16A2
# CLCA4
# ZNF33B
# CUBNP1
# BMS1
# CSGALNACT2
# RASGEF1A
# ATRX
# MAPK10
# GCNT2
# SLC10A6
# TFAP2A-AS1
# TFAP2A
# TMEM150C
# FTX
# C4orf22
# SEPT11
# G3BP2
# ARHGEF17
# SCARB2
# TEX11
# ZEB1
# SHROOM3
# NLGN3
# NONO
# FGF5
# MTF2
# CCNG2
# NHLRC4
# PIGQ
# KIAA1107
# BTBD8
# ZNF705E
# LINC00840
# FAM13A
# ST6GALNAC3
# NRXN2
# FAM13C
# LL0XNC01-116E7.2
# TMSB15B
# ADAMTS2
# ZNF354C
# IL1RAPL2
# HMOX2
# CTNNA3
# LEF1
# LRRTM3
# ZNF354A
# ROGDI
# GLYR1
# CPT2
# SLC1A7
# MYO1D
# LEF1-AS1
# PAPSS1
# CCSER1
# ARHGAP22
# DACH2
# PDLIM5
# NEGR1
# STPG2-AS1
# TSPAN5
# MRPL11
# GNG12-AS1
# XRCC6P5
# TM2D1
# GMDS
# MTND5P5
# SLC39A8
# TBCK
# PCDH15
# AIMP1
# BTNL8
# DBT
# EXTL2
# SLC4A4
# N4BP2
# KLHL5
# CHST7
# KLB
# RPL9
# LIAS
# PDS5A
# EXD3
# RHOH
# FAM114A1
# DYNC2H1
# ZNF81
# LIMCH1
# FANCI
# TRPC6
# COX7B2
# JRKL
# MRPL45P2
# TLR1
# CEP57
# CCDC149
# LDB2
# IGF2BP1
# NCAM1
# NCAPG
# LCORL
# GPSM1
# KCNIP4
# HOXB-AS3
# KLF3
# HOXB3
# ANAPC4
# SLC34A2
# ARAP2
# MIR4801
# C4orf19
# TBC1D1
# AKR1C2
# TUBAL3
# GPR158
# DLG2
# RPL17P19
# FAM188A
# VPS33B
# CENPC
# SV2B
# UBA6
# TMPRSS11GP
# UGT2B15
# NOA1
# MLLT10
# DNAJC1
# TTC23
# MSRB2
# VAV3
# NTNG1
# OTUD1
# IGFBP7
# ARL9
# NFXL1
# CWH43
# NIPAL1
# TXK
# MAB21L3
# PPFIBP1
# PIWIL4
# FUT4
# OCIAD1
# LRRC66
# SRP72
# GATA3
# GATA3-AS1
# MIR4449
# CCDC3
# CEP135
# RNA5SP162
# RPL7AP31
# ACBD6
# KLHL14
# PTPRM
# RGSL1
# PIWIL2
# KCNH8
# ZNF725P
# IGKV2-28
# ZNF91
# EGR3
# ABHD12
# ATL1
# RNF17
# HECW1-IT1
# HECW1
# CHMP3
# RNF103-CHMP3
# SGCG
# GADL1
# GLI3
# OSBPL10
# CDK13
# GPD1L
# RBPMS-AS1
# RBPMS
# LPL
# MTMR7
# MIPOL1
# LIPT1
# CNTN6
# WBSCR17
# ITPR1
# EGOT
# PCNA
# CDS2
# GRM7-AS3
# SRGAP3
# MITD1
# TSGA10
# MSR1
# PRKD1
# LINC00599
# RPS12P24
# ESF1
# EGLN3
# ATG7
# FRY
# DLC1
# FBLN2
# TCF7L1
# NRG1
# SUSD5
# STK4
# RIMBP2
# PTPRT
# TMEM132D
# TCEA1
# GLT1D1
# CYP4F22
# ACTN1
# PKIG
# WISP2
# SDC4
# PXDNL
# SBNO1
# LIMD1
# NKAIN3
# SIPA1L1
# WFDC3
# NUMB
# RAPGEF5
# CCDC88A
# ABCB5
# GMCL1
# CREB5
# KIAA0586
# RPS29P2
# RTN1
# ITGA9
# DPY19L2P1
# RTKN
# WDR54
# SIX1
# BBS9
# SFRP1
# MIR548AO
# CYP4F34P
# ACTR5
# KCNH5
# CCDC129
# MANBAL
# CPAMD8
# SNHG17
# CHURC1-FNTB
# SNORA71D
# FNTB
# MAX
# CHL1
# GCC2
# SH3RF3
# DENND2A
# DPPA5P1
# DGKI
# LUC7L2
# MYO3B
# C7orf55-LUC7L2
# TRIM56
# MUC12
# LRP2
# ABCB11
# AGK
# SLC1A5
# TBC1D4
# KLF12
# PIBF1
# USP37
# PLCD4
# WNT10A
# ZNF223
# ZNF222
# ZNF155
# ZNF528
# NUP205
# TNFAIP6
# ABCC4
# NALCN-AS1
# CAV1
# CADPS2
# BIVM
# BIVM-ERCC5
# RPL7L1P12
# STK24
# PNPLA8
# UGGT2
# SESTD1
# FBXL13
# ATXN7L1
# GPC6
# FAM117B
# ICA1L
# LHFPL3
# RELN
# HOXD4
# MIR10B
# HOXD3
# MIR4773-1
# FABP5P10
# MALL
# MLPH
# RHEB
# CNTNAP5
# PRKAG2
# PRKAG2-AS1
# GLI2
# GSAP
# SCTR
# LGALS13
# DPP10
# UBE3C
# ZNF814
# HIP1
# PAPL
# NSFL1C
# SIRPB2
# KBTBD11
# KBTBD11-OT1
# MCPH1
# ANGPT2
# ANKMY1
# AKT2
# ZNF587
# PAX3
# AGFG1
# FAM131B
# ZEB2
# ACSL3
# DYNC1I1
# PSG7
# LRP1B
# PSG6
# TMEM86B
# PPP6R1
# RAB3GAP1
# ZNF587B
# SAMD9
# NLRP8
# SPATA3
# CLDN12
# WDFY2
# ZNF805
# DIS3L2P1
# ZNF548
# PCLO
# ANAPC5
# ACYP2
# LIN52
# ARMC2
# PRSS38
# CCDC171
# ANKRD52
# CDC42BPA
# ADCK3
# MLLT3
# GSK3B
# STXBP5L
# ILDR1
# SLC30A10
# GOPC
# C9orf72
# GAB4
# KCNK2
# RTN4IP1
# MICAL3
# RHEBP3
# SNORA16B
# PPP2R5A
# OR4Q1P
# LDHAP4
# CEP85L
# RUVBL1
# ZNF250
# MAFA
# GREM2
# DAZAP1
# ST3GAL6
# PDLIM1P4
# COL8A1
# TAAR7P
# B3GALNT2
# SRGAP1
# DISC1-IT1
# C3orf17
# DISC1
# ZNF252P
# TMED10P1
# HMGN1
# ZNF252P-AS1
# KANK1
# GLIS3
# ABCG1
# GTPBP8
# ESPL1
# NIPA2
# IL10RB
# ZNF519
# LAMA3
# RBP1
# PFKM
# FAM189A1
# MIB1
# DENND1B
# ARID2
# U2SURP
# CFH
# PTPN2
# LCA5
# CEP76
# EYS
# PHF3
# GS1-279B7.1
# TRPM3
# C9orf85
# IPO8
# TRPM6
# TMTC1
# GABRG3
# PCCB
# KRT18P62
# P2RX6P
# UBAP1
# KIF24
# KLHL32
# GP9
# PIAS2
# TMCC1
# LINC00669
# FHOD3
# POU6F1
# TMCC2
# EPHB1
# DIP2B
# LRRN2
# OR13J1
# NDUFA5P4
# PPP1R15B
# ASXL3
# STOX1
# RNF38
# SNAP91
# WDR64
# C21orf62
# FSHR
# RUNX1T1
# ATP6V0D2
# CARD11
# GNA12
# AMZ1
# CACNA2D2
# MRPS16P2
# ZNF831
# TRMT61B
# PLB1
# CDH4
# SMARCA4
# RIN3
# SUN1
# OGFR
# COL9A3
# PREB
# ABHD1
# C8orf37
# IFI27L1
# IFI27
# DNM2
# FEZ2
# MATN2
# CAMKMT
# MSH2
# TTC7A
# MCFD2
# PTGIS
# BATF
# THSD7A
# PRKCE
# SRBD1
# LY96
# NXPH1
# TBX3
# CRISPLD1
# RPA3
# THADA
# ZFP36L2
# ZNF69
# SLC8A1
# MRPS28
# KSR2
# MED13L
# PPP4R4
# RFX4
# SYNJ1
# ZNF717
# COL14A1
# LINC00299
# PLEKHG1
# ADAMTS5
# TMEM65
# RPL23P2
# RWDD2B
# CASC8
# STXBP5
# MGAT4C
# BTG3
# EFR3A
# CELF5
# PTPRQ
# OTOGL
# FAM135B
# PTK2
# LINC00879
# EFCAB2
# IFNGR1
# ENPP2
# CXADR
# FBN3
# SOD2
# ERC2
# ATG2B
# PARK2
# UBR5
# C2orf44
# MFSD2B
# ACAT2
# IGHV1OR21-1
# WDR35
# CISD1P1
# SLC25A26
# RSPH3
# OXR1
# KCNS3
# RSPO2
# CADPS
# ANKS1B
# TRPS1
# EIF3H
# USP25
# ANK2
# GGACT
# OR5BB1P
# LINC00616
# LINC00499
# ADAMTS12
# DRD4
# GRAMD3
# ZCCHC10
# SLC7A11-AS1
# METTL15
# AFF4
# CD6
# RERE
# FCHO2
# FHAD1
# ANKHD1
# ANKHD1-EIF4EBP3
# RAPGEF2
# PLCXD3
# NAF1
# TMEM144
# OR2D3
# MEGF10
# ZNF215
# RBMY2JP
# ALDOC
# CTCF
# RXFP1
# COX10-AS1
# LINC00670
# SPAG5
# OR5G5P
# ELAC2
# HS3ST3A1
# EPB41
# PDGFRB
# CDH13
# VCAN
# PARP8
# ANKRD50
# SLC25A33
# TMEM201
# ABHD15
# RPL29P14
# CSNK1A1
# EIF4G3
# INTU
# MAN2A1
# TAS2R1
# TMEM232
# PDE4D
# EDIL3
# C11orf96
# ATRNL1
# MFSD8
# LINC00304
# NDE1
# CYSTM1
# CDH15
# MYH11
# STK10
# TVP23C-CDRT4
# VWA5B1
# TVP23C
# C4orf29
# SCLT1
# ANKRD11
# PIPOX
# TMEM161B-AS1
# CDRT1
# LARP1B
# PRRC1
# TOX3
# HPSE2
# MACF1
# FOXJ3
# PLRG1
# DUSP8
# MIR4694
# EBF1
# PCDHA13
# GRIA1
# NRG3
# ERAP1
# PCDHA12
# PCDHA11
# SLC7A6
# SLC7A6OS
# NMUR2
# PCDHB14
# CNTF
# TMC7
# TLR2
# OR9I2P
# GLP2R
# PCDHB9
# RCVRN
# PIK3R5
# NAV2
# GAS7
# ARHGAP10
# PCDHB10
# PRKCB
# PCDHB12
# KIAA0754
# LPXN
# ZFP91-CNTF
# MUC5B
# SLC1A3
# AHRR
# RNF150
# IL15
# TENM2
# SLC17A6
# USP10
# MANEAL
# MCTP1
# TRPV3
# PCDHA10
# ASPA
# LINC00856
# RNF220
# COQ7
# SPATA22
# CLGN
# PCDHA1
# CHID1
# PCDHA2
# INPP4B
# PCDHA3
# PCDHA4
# GIF
# TMC5
# ST3GAL3
# GAB1
# PCDHA5
# SZRD1
# PCDHA6
# PCDHA7
# PCDHA8
# PRDM16
# PCDHA9
# KIF1B
# ATP2A3
# HPGD
# LINC00922
# MKL2
# HSD17B12
# ATF7IP2
# NPFFR1
# NEK1
# SORBS1
# TRPC5OS
# WDR59
# CLEC16A
# PRR5L
# VN1R70P
# TEAD1
# NETO2
# OSBPL9
# SPON1
# DCX
# SORCS1
# SERPINF1
# ADAM29
# TMEM219
# LRRC4C
# STK32C
# ADAT1
# ZBTB8A
# SEC24D
# FBXO2
# MIR129-2
# COMMD10
# HELLS
# SERBP1P2
# MFAP3L
# PEX14
# HTR2C
# MCC

# %%
body_genes = ['KCNIP4', 'MALAT1', 'LHFPL3', 'LRRC4C', 'CSMD1', 'PCDH9', 'ERBB4', 'NRXN1', 'DMD',
              'IL1RAPL1', 'XIST', 'LSAMP', 'SOX2-OT', 'GRIA2', 'GRM5', 'TNR', 'PTPRG', 'PDZD2',
              'GRIA4', 'NTM', 'GALNT13', 'NPAS3', 'SHISA9', 'MARCH1', 'NTRK2', 'PHF14', 'ZSWIM6',
              'PTPRZ1', 'GPM6A', 'NFIB', 'PCDH15', 'ANKS1B', 'SOX5', 'NEGR1', 'TMEM108', 'ANK2',
              'SLC8A1', 'SPOCK3', 'PDE4B', 'CALM2', 'FGF14', 'LPPR1', 'MAPK10', 'NAV1', 'IL1RAP',
              'FHIT', 'NLGN4X', 'PDE4D', 'KAZN', 'FAM155A', 'GPC6', 'DOCK4', 'COL9A1', 'PTPRD',
              'ZNF521', 'CPE', 'OLIG1', 'SEZ6L', 'ANK3', 'MAGI2', 'LRFN5', 'DNER', 'GLCCI1', 'PSD3',
              'ASTN2', 'DCAF6', 'SORCS1', 'FGF12', 'XYLT1', 'GRID2', 'RGS7', 'TJP1', 'ALCAM', 'NCAM2',
              'CTTNBP2', 'GRM7', 'FTH1', 'GUCY1A2', 'FAF1', 'PLXDC2', 'SEMA6A', 'FBXL17', 'OPCML',
              'ZNF638', 'MEIS2', 'NOL4', 'TCF12', 'ZFPM2', 'DNM3', 'PPFIA2', 'AGAP1', 'NLGN1', 'LPP',
              'ADARB2', 'ZHX3', 'PHACTR3', 'SIK3', 'CCSER1', 'GSK3B', 'PRTFDC1'
             ]
promoter_genes = ['KCNIP4', 'LHFPL3', 'MALAT1', 'NRXN1', 'CSMD1', 'PCDH9', 'LRRC4C', 'ERBB4',
                  'PCDH15', 'LSAMP', 'XIST', 'TNR', 'DMD', 'IL1RAPL1', 'GRIA2', 'NPAS3', 'NTM',
                  'MARCH1', 'GRM5', 'SOX2-OT', 'GALNT13', 'GRIA4', 'NTRK2', 'NFIB', 'GPM6A',
                  'ANK2', 'PTPRZ1', 'ANKS1B', 'ASTN2', 'FGF14', 'NEGR1', 'SHISA9', 'KAZN',
                  'DOCK4', 'MAGI2', 'ZSWIM6', 'SLC8A1', 'LPPR1', 'SPOCK3', 'SOX5', 'PDZD2',
                  'IL1RAP', 'PTPRD', 'PDE4B', 'GPC6', 'NLGN1', 'ZNF521', 'FAM155A', 'PDE4D',
                  'OPCML', 'NLGN4X', 'CPE', 'CLASP2', 'FHIT', 'SCD5', 'KCNMB2', 'PHF14', 'GRM7',
                  'RGS7', 'DNER', 'SEZ6L', 'HIP1', 'PPP1R12A', 'SLC44A5', 'TMEM132C', 'MAPK10',
                  'GRID2', 'TMEM108', 'TJP1', 'SORCS1', 'RFTN2', 'GSK3B', 'CTTNBP2', 'VCAN', 'NCAM2',
                  'N4BP2L2', 'PSD3', 'ANKRD17', 'PREX2', 'COL9A1', 'SIK3', 'SORBS2', 'JMJD1C',
                  'PLXDC2', 'CCSER1', 'PPFIA2', 'AGAP1', 'DPP10', 'PTPRG', 'RIT2', 'ZNF638', 'NFIA',
                  'XYLT1', 'SNTG1', 'CPEB4', 'LRFN5', 'KLHL13', 'ZHX3', 'CST3', 'RIN2'
                 ]

def get_space_approach_genes(genes):
    return [_name for _name in genes if _name in _test.index]

# %%
get_space_approach_genes(body_genes)
# Out:
# ['KCNIP4',
#  'LHFPL3',
#  'LRRC4C',
#  'CSMD1',
#  'DMD',
#  'LSAMP',
#  'SOX2-OT',
#  'NPAS3',
#  'MARCH1',
#  'GPM6A',
#  'PCDH15',
#  'ANKS1B',
#  'SOX5',
#  'NEGR1',
#  'ANK2',
#  'SLC8A1',
#  'LPPR1',
#  'MAPK10',
#  'FHIT',
#  'PDE4D',
#  'FAM155A',
#  'GPC6',
#  'PTPRD',
#  'ASTN2',
#  'SORCS1',
#  'GRID2',
#  'OPCML',
#  'LPP',
#  'CCSER1',
#  'GSK3B']

# %%
get_space_approach_genes(promoter_genes)
# Out:
# ['KCNIP4',
#  'LHFPL3',
#  'CSMD1',
#  'LRRC4C',
#  'PCDH15',
#  'LSAMP',
#  'DMD',
#  'NPAS3',
#  'MARCH1',
#  'SOX2-OT',
#  'GPM6A',
#  'ANK2',
#  'ANKS1B',
#  'ASTN2',
#  'NEGR1',
#  'SLC8A1',
#  'LPPR1',
#  'SOX5',
#  'PTPRD',
#  'GPC6',
#  'FAM155A',
#  'PDE4D',
#  'OPCML',
#  'FHIT',
#  'HIP1',
#  'MAPK10',
#  'GRID2',
#  'SORCS1',
#  'GSK3B',
#  'VCAN',
#  'JMJD1C',
#  'CCSER1',
#  'DPP10',
#  'SNTG1']
